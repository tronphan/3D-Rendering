# %%
import pandas as pd
import matplotlib as plt

# %%
path = "dataset/blur.csv"
variances = pd.read_csv(path)

# %%
from sklearn.cluster import KMeans
value = np.array(variances["variance"])
kmeans = KMeans(n_clusters=2, random_state=42).fit(value.reshape(-1,1))
centroid = kmeans.cluster_centers_
print(centroid)
# Out:
# [[241.66614269]
#  [ 73.43654421]]

# %%
(centroid[0] + centroid[1])/2
# Out:
# array([157.55134345])

# %%
ls = [1, 10 ,100]
variances.iloc[ls]
# Out:
#      idx    variance
# 1      1  340.279281
# 10    10  329.985646
# 100  100  122.367008

# %%
import pandas as pd
data = pd.read_csv("dataset/realsense/camera_pose.csv")

# %%
ls = range(100,150)
print(ls[0])
# Out:
# 100

# %%
pose_data = data.iloc[100:110]
for i in range(len(pose_data.index)):
        print(pose_data.iloc[i])
# Out:
# Frame count           100.000000
# Pos x                  -0.030404
# Pos y                  -0.005218
# Pos z                   0.630284
# Rot x                  -0.089864
# Rot y                  -0.151912
# Rot z                  -0.011183
# Rot w                   0.984237
# Tracker confidence      3.000000
# Name: 100, dtype: float64
# Frame count           101.000000
# Pos x                  -0.025326
# Pos y                  -0.014721
# Pos z                   0.631210
# Rot x                  -0.095973
# Rot y                  -0.157165
# Rot z                  -0.012950
# Rot w                   0.982813
# Tracker confidence      3.000000
# Name: 101, dtype: float64
# Frame count           102.000000
# Pos x                  -0.021865
# Pos y                  -0.024497
# Pos z                   0.631851
# Rot x                  -0.104265
# Rot y                  -0.158360
# Rot z                  -0.014724
# Rot w                   0.981751
# ...

# %%
data.iloc[0:100]
# Out:
#     Frame count     Pos x     Pos y     Pos z     Rot x     Rot y     Rot z  \
# 0             0 -0.063186  0.084948 -0.018365  0.025163  0.254865 -0.044434
# 1             1 -0.069634  0.081027 -0.008808  0.035320  0.251670 -0.028075
# 2             2 -0.071753  0.077573 -0.004314  0.035117  0.252283 -0.025742
# 3             3 -0.072352  0.076452 -0.003767  0.034302  0.248141 -0.024311
# 4             4 -0.072238  0.073569 -0.006944  0.035030  0.236918 -0.020009
# 5             5 -0.071100  0.072087 -0.010084  0.037596  0.230198 -0.018158
# 6             6 -0.071659  0.071264 -0.012015  0.037720  0.226428 -0.017167
# 7             7 -0.071537  0.069587 -0.014186  0.038936  0.223127 -0.016306
# 8             8 -0.068652  0.070436 -0.014213  0.040630  0.219042 -0.014315
# 9             9 -0.068366  0.066848 -0.014227  0.040420  0.217550 -0.011720
# 10           10 -0.066674  0.064598 -0.013548  0.040807  0.216332 -0.009299
# ...
